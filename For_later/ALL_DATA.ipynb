# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from tqdm import tqdm

pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

# %%
table = pd.read_html('https://www.basketball-reference.com/play-index/psl_finder.cgi?request=1&match=single&type=totals&per_minute_base=36&per_poss_base=100&lg_id=NBA&is_playoffs=N&year_min=1980&year_max=2019&franch_id=&season_start=1&season_end=-1&age_min=0&age_max=99&shoot_hand=&height_min=0&height_max=99&birth_country_is=Y&birth_country=&birth_state=&college_id=&draft_year=&is_active=&debut_yr_nba_start=1980&debut_yr_nba_end=2019&is_hof=&is_as=&as_comp=gt&as_val=0&award=&pos_is_g=Y&pos_is_gf=Y&pos_is_f=Y&pos_is_fg=Y&pos_is_fc=Y&pos_is_c=Y&pos_is_cf=Y&qual=&c1stat=per&c1comp=gt&c1val=-10000&c2stat=gs&c2comp=gt&c2val=-100&c3stat=ws&c3comp=gt&c3val=-100000&c4stat=&c4comp=&c4val=&c5stat=&c5comp=&c6mult=&c6stat=&order_by=season&order_by_asc=&offset=15100',header=1, index_col='Rk')

# df = table[0]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-4b9471cf4db0> in <module>
# ...

# %%
def get_all_data():
    df = pd.DataFrame()
    for i in tqdm(range(0,15300,100)):
        table = pd.read_html(f'https://www.basketball-reference.com/play-index/psl_finder.cgi?request=1&match=single&type=totals&per_minute_base=36&per_poss_base=100&lg_id=NBA&is_playoffs=N&year_min=1980&year_max=2019&franch_id=&season_start=1&season_end=-1&age_min=0&age_max=99&shoot_hand=&height_min=0&height_max=99&birth_country_is=Y&birth_country=&birth_state=&college_id=&draft_year=&is_active=&debut_yr_nba_start=1980&debut_yr_nba_end=2019&is_hof=&is_as=&as_comp=gt&as_val=0&award=&pos_is_g=Y&pos_is_gf=Y&pos_is_f=Y&pos_is_fg=Y&pos_is_fc=Y&pos_is_c=Y&pos_is_cf=Y&qual=&c1stat=per&c1comp=gt&c1val=-10000&c2stat=gs&c2comp=gt&c2val=-100&c3stat=ws&c3comp=gt&c3val=-100000&c4stat=&c4comp=&c4val=&c5stat=&c5comp=&c6mult=&c6stat=&order_by=season&order_by_asc=&offset={i}',header=1, index_col='Rk')
        df = pd.concat([df,table[0]])
        
    return df

# %%
df = get_all_data()
# Out:
# 100%|██████████| 153/153 [02:50<00:00,  1.17s/it]

# %%
df = df.reset_index()

# %%
df = df[df.PTS != 'PTS']

# %%
df.to_pickle('better_data.pickle')

# %%
df
# Out:
#           Rk                  Player Age   Tm   Lg   PER  GS    WS   Season  \
# 0          1            Álex Abrines  25  OKC  NBA   6.3   2   0.6  2018-19
# 1          2              Quincy Acy  28  PHO  NBA   2.9   0  -0.1  2018-19
# 2          3            Jaylen Adams  22  ATL  NBA   7.6   1   0.1  2018-19
# 3          4            Steven Adams  25  OKC  NBA  18.5  80   9.1  2018-19
# 4          5             Bam Adebayo  21  MIA  NBA  17.9  28   6.8  2018-19
# 5          6               Deng Adel  21  CLE  NBA   2.7   3  -0.2  2018-19
# 6          7  DeVaughn Akoon-Purcell  25  DEN  NBA   8.2   0   0.0  2018-19
# 7          8       LaMarcus Aldridge  33  SAS  NBA  22.9  81   9.3  2018-19
# 8          9            Rawle Alkins  21  CHI  NBA   8.1   1  -0.1  2018-19
# 9         10           Grayson Allen  23  UTA  NBA   7.5   2   0.0  2018-19
# 10        11           Jarrett Allen  20  BRK  NBA  18.5  80   7.6  2018-19
# ...

# %%
df['year'] = 2018

# %%
df
# Out:
#           Rk                  Player Age   Tm   Lg   PER  GS    WS   Season  \
# 0          1            Álex Abrines  25  OKC  NBA   6.3   2   0.6  2018-19
# 1          2              Quincy Acy  28  PHO  NBA   2.9   0  -0.1  2018-19
# 2          3            Jaylen Adams  22  ATL  NBA   7.6   1   0.1  2018-19
# 3          4            Steven Adams  25  OKC  NBA  18.5  80   9.1  2018-19
# 4          5             Bam Adebayo  21  MIA  NBA  17.9  28   6.8  2018-19
# 5          6               Deng Adel  21  CLE  NBA   2.7   3  -0.2  2018-19
# 6          7  DeVaughn Akoon-Purcell  25  DEN  NBA   8.2   0   0.0  2018-19
# 7          8       LaMarcus Aldridge  33  SAS  NBA  22.9  81   9.3  2018-19
# 8          9            Rawle Alkins  21  CHI  NBA   8.1   1  -0.1  2018-19
# 9         10           Grayson Allen  23  UTA  NBA   7.5   2   0.0  2018-19
# 10        11           Jarrett Allen  20  BRK  NBA  18.5  80   7.6  2018-19
# ...

# %%
df = pd.read_pickle('final_df.pickle')

# %%
df
# Out:
#         rk                 player pos  age   tm   g    gs    mp   fg   fga  \
# 5991     1    Kareem Abdul-Jabbar   C   32  LAL  82   NaN  3143  835  1383
# 5992     2          Tom Abernethy  PF   25  GSW  67   NaN  1222  153   318
# 5993     3            Alvan Adams   C   25  PHO  75   NaN  2168  465   875
# 5994     4         Tiny Archibald  PG   31  BOS  80  80.0  2864  383   794
# 5995     5          Dennis Awtrey   C   31  CHI  26   NaN   560   27    60
# 5996     6             Gus Bailey  SG   28  WSB  20   NaN   180   16    35
# 5997     7           James Bailey  PF   22  SEA  67   NaN   726  122   271
# 5998     8           Greg Ballard  SF   25  WSB  82   NaN  2438  545  1101
# 5999     9            Mike Bantom  SF   28  IND  77   NaN  2330  384   760
# 6000    10          Marvin Barnes  PF   27  SDC  20   NaN   287   24    60
# 6001    11             Rick Barry  SF   35  HOU  72   NaN  1816  325   771
# ...

# %%
df.plot(x=df.index, y='ws')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-5c3214e53deb> in <module>
# ----> 1 df.plot(x=df.index, y='ws')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
#    2943     __call__.__doc__ = plot_frame.__doc__
#    2944
#
# ...

# %%
df[['2p']].plot()
df[['ws']].plot()

# %%
df
# Out:
#         rk                 player pos  age   tm   g    gs    mp   fg   fga  \
# 5991     1    Kareem Abdul-Jabbar   C   32  LAL  82   NaN  3143  835  1383
# 5992     2          Tom Abernethy  PF   25  GSW  67   NaN  1222  153   318
# 5993     3            Alvan Adams   C   25  PHO  75   NaN  2168  465   875
# 5994     4         Tiny Archibald  PG   31  BOS  80  80.0  2864  383   794
# 5995     5          Dennis Awtrey   C   31  CHI  26   NaN   560   27    60
# 5996     6             Gus Bailey  SG   28  WSB  20   NaN   180   16    35
# 5997     7           James Bailey  PF   22  SEA  67   NaN   726  122   271
# 5998     8           Greg Ballard  SF   25  WSB  82   NaN  2438  545  1101
# 5999     9            Mike Bantom  SF   28  IND  77   NaN  2330  384   760
# 6000    10          Marvin Barnes  PF   27  SDC  20   NaN   287   24    60
# 6001    11             Rick Barry  SF   35  HOU  72   NaN  1816  325   771
# ...

# %%
df.reset_index()
# Out:
#        index   rk                 player pos  age   tm   g    gs    mp   fg  \
# 0       5991    1    Kareem Abdul-Jabbar   C   32  LAL  82   NaN  3143  835
# 1       5992    2          Tom Abernethy  PF   25  GSW  67   NaN  1222  153
# 2       5993    3            Alvan Adams   C   25  PHO  75   NaN  2168  465
# 3       5994    4         Tiny Archibald  PG   31  BOS  80  80.0  2864  383
# 4       5995    5          Dennis Awtrey   C   31  CHI  26   NaN   560   27
# 5       5996    6             Gus Bailey  SG   28  WSB  20   NaN   180   16
# 6       5997    7           James Bailey  PF   22  SEA  67   NaN   726  122
# 7       5998    8           Greg Ballard  SF   25  WSB  82   NaN  2438  545
# 8       5999    9            Mike Bantom  SF   28  IND  77   NaN  2330  384
# 9       6000   10          Marvin Barnes  PF   27  SDC  20   NaN   287   24
# 10      6001   11             Rick Barry  SF   35  HOU  72   NaN  1816  325
# ...
